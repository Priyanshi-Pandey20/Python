# %% [markdown]
# ADVANCE OPERATION WITH BUSINESS EXAMPLES

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Data structure : [restaurant_id,2021,2022,2023,2024]
sales_data = np.array([
    [1,15000,18000,22000,250000], #Biryani
    [2,12000,14000,16000,190000],#Bejing bites
    [3,20000,230000,260000,300000], #Pizza
    [4,180000,210000,240000,270000], #Burger Point
    [5,160000,185000,205000,230000], #Chai Point

])

print("===Zomato sales analysis===")
print("\n Sales data shape",sales_data.shape)
print("\n Sample data for 1st 3 restau:",sales_data[:3])
# Out:
# ===Zomato sales analysis===
#
#  Sales data shape (5, 5)
#
#  Sample data for 1st 3 restau: [[     1  15000  18000  22000 250000]
#  [     2  12000  14000  16000 190000]
#  [     3  20000 230000 260000 300000]]

# %%
#total sales per year
import numpy as np
print(np.sum(sales_data,axis=0))
yeary_total = np.sum(sales_data[:,1:],axis=1)
print(yeary_total)


#Minimum sales per restaurant
min_sales = np.min(sales_data[:,1:],axis=1)
print(min_sales)

#Maximum sales per year
max_sales = np.max(sales_data[:,1:],axis=0)
print(max_sales)


#Average sales per restaurant
avg_sales = np.mean(sales_data[:,1:],axis=1)
print(avg_sales)
# Out:
# [     15  387000  657000  743000 1240000]
# [305000 232000 810000 900000 780000]
# [ 15000  12000  20000 180000 160000]
# [180000 230000 260000 300000]
# [ 76250.  58000. 202500. 225000. 195000.]

# %%
cumsum = np.cumsum(sales_data[:,1:],axis=1)
print(cumsum)

plt.figure(figsize=(10,6))
plt.plot(np.mean(cumsum,axis=0))
plt.title("Average cumulative sales accross all restaurants")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# [[ 15000  33000  55000 305000]
#  [ 12000  26000  42000 232000]
#  [ 20000 250000 510000 810000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
vector1 = np.array([1,2,3,4,5])
vector2 = np.array([6,7,8,9,10])

print("Vector addition: ",vector1+vector2)
print("Multiplication vector: ",vector1 * vector2)
print("Dot Product ",np.dot(vector1,vector2))

angle = np.arccos(np.dot(vector1,vector2)/(np.linalg.norm(vector1)*np.linalg.norm(vector2)))
print(angle)
# Out:
# Vector addition:  [ 7  9 11 13 15]
# Multiplication vector:  [ 6 14 24 36 50]
# Dot Product  130
# 0.26554161733900966

# %%
restaurant_types = np.array(['biryani','chinese','pizza','burger','cafe'])
vectorized_upper = np.vectorize(str.upper)
print("Vectorized Upper",vectorized_upper(restaurant_types))
# Out:
# Vectorized Upper ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %%
#Brodcast
monthly_avg = sales_data[:,1:] / 12 

print(monthly_avg)
# Out:
# [[ 1250.          1500.          1833.33333333 20833.33333333]
#  [ 1000.          1166.66666667  1333.33333333 15833.33333333]
#  [ 1666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
